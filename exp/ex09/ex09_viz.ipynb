# %%
import os 
import sys
import matplotlib.pyplot as plt
import pandas as pd

repo_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(repo_root)

from src import *
from src.models.BradleyTerry import *
from tst.tst_weight_conversion.old_newman import *

# %%
file_path = os.path.join(repo_root, 'exp', 'ex09', 'data', 'Hyperedge_iteration_count.csv')
df = pd.read_csv(file_path) 
grouped = df.groupby('K')['Iterations_to_converge'].mean().reset_index()

# %%
print(grouped)
# Out:
#      K  Iterations_to_converge
# 0    2                   40.45
# 1    5                   31.54
# 2   10                   34.79
# 3   15                   38.15
# 4   20                   40.02
# 5   25                   41.34
# 6   30                   42.10
# 7   35                   43.40
# 8   40                   44.60
# 9   45                   45.23
# 10  50                   45.22

# %%
plt.plot(grouped['K'], grouped['Iterations_to_converge'])
