# %%
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

repo_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(repo_root)

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'results', 'ex06.1'))
plt.figure(figsize=(10, 6))
plt.plot(df['m'], df['std_model'], marker='o', label='std_model')
plt.plot(df['m'], df['old_newman'], marker='o', label='old_newman')
plt.plot(df['m'], df['parrallel'], marker='o', label='parrallel')
plt.plot(df['m'], df['numba'], marker='o', label='numba')

# Adding titles and labels
plt.title('Performance Comparison')
plt.xlabel('m')
plt.ylabel('Time (in seconds)')
plt.yscale('log')
plt.xscale('log')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(os.path.join(os.getcwd(), 'results', 'ex06.1'))
#       2 plt.figure(figsize=(10, 6))
#       3 plt.plot(df['m'], df['std_model'], marker='o', label='std_model')
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'results', 'ex06.2'))
plt.figure(figsize=(10, 6))
plt.plot(df['n'], df['std_model'], marker='o', label='std_model')
plt.plot(df['n'], df['old_newman'], marker='o', label='old_newman')
plt.plot(df['n'], df['parrallel'], marker='o', label='parrallel')
plt.plot(df['n'], df['numba'], marker='o', label='numba')

# Adding titles and labels
plt.title('Performance Comparison')
plt.xlabel('n')
plt.ylabel('Time (seconds)')
plt.xscale('log')
plt.legend()

plt.show()

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'results', 'ex06.3'))
plt.figure(figsize=(10, 6))
plt.plot(df['k'], df['std_model'], marker='o', label='std_model')
plt.plot(df['k'], df['old_newman'], marker='o', label='old_newman')
plt.plot(df['k'], df['parrallel'], marker='o', label='parrallel')
plt.plot(df['k'], df['numba'], marker='o', label='numba')

# Adding titles and labels
plt.title('Performance Comparison')
plt.xlabel('k')
plt.ylabel('Time (seconds)')
plt.legend()

plt.show()
