# %%
import os
import sys
import csv
from sklearn.metrics import roc_auc_score, roc_curve

repo_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(repo_root)

from src.solvers import *
from src.syntetic import *
from src.file_readers import * 
from exp.experiment_helpers.metrics import * 
from exp.experiment_helpers.model_evaluation import * 
from exp.experiment_helpers.file_handlers import *

# %%
process_data_directory('data',  'ex01_results.csv')

# %% [markdown]
# ## testing M

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i, m in enumerate(M_values):
    ax = axes[i]
    ax.plot(train_sizes,  results_M_std[m], label='std_bt_likelihood')
    ax.plot(train_sizes, results_M_ho[m], label='ho_bt_likelihood')
    ax.hlines(1, 0.01, 1.0, colors='gray', linestyles='dashed')
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Train size')
    ax.set_ylabel('Likelihood' if i == 0 else '')
    ax.set_title(f'M = {m}')
    ax.set_xscale('log')
    ax.legend()



plt.show()

# %% [markdown]
# ## testing game size

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i, K1 in enumerate(K1_values):
    ax = axes[i]
    ax.plot(train_sizes, results_K_std[K1], label='std_bt_likelihood')
    ax.plot(train_sizes, results_K_ho[K1], label='ho_bt_likelihood')
    ax.hlines(1, 0.01, 1.0, colors='gray', linestyles='dashed')
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Train size')
    ax.set_ylabel('Likelihood' if i == 0 else '')
    ax.set_title(f'K1={K1}')
    ax.set_xscale('log')
    ax.legend()

# %% [markdown]
# ## testing K gap size

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

for i, Kgap in enumerate(K2_values):
    ax = axes[i]
    ax.plot(train_sizes, results_Kgap_std[Kgap], label='std_bt_likelihood')
    ax.plot(train_sizes, results_Kgap_ho[Kgap], label='ho_bt_likelihood')
    ax.hlines(1, 0.01, 1.0, colors='gray', linestyles='dashed')
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Train size')
    ax.set_ylabel('Likelihood' if i == 0 else '')
    ax.set_title(f'gapping in k={Kgap}')
    ax.set_xscale('log')
    ax.legend()
