# %%
import os
import sys
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

repo_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(repo_root)

from src.solvers import *
from src.syntetic import *
from src.file_readers import * 
from exp.experiment_helpers.metrics import * 
from exp.experiment_helpers.model_evaluation import * 
from exp.experiment_helpers.file_handlers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       6 import pandas as pd
#       8 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# ----> 9 from src.solvers import *
#      10 from src.syntetic import *
#      11 from src.file_readers import *
#
# ModuleNotFoundError: No module named 'src'

# %%
process_directory('data',  'ex03_results.csv')

# %%
df = pd.read_csv('ex03_results.csv')

# %%
sns.displot(df, x='ho_bt_likelihood', hue='dataset', kind='kde')
sns.displot(df, x='std_bt_likelihood', hue='dataset', kind='kde')

# %%
grouped = df.groupby(['dataset'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 grouped, _ = df.groupby(['dataset'])
#       3 print(grouped)
#       6 sns.displot(df, x="std_bt_likelihood", kind="kde")
#
# ValueError: too many values to unpack (expected 2)
